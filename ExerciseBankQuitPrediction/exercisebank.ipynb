# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("churn.csv", sep=',')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#number rows and columns
df.shape[0]
df.shape[1]
# Out:
# 14

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['CustomerId'].unique()
# Out:
# array([15634602, 15647311, 15619304, ..., 15584532, 15682355, 15628319],
#       shape=(10000,))

# %%
print(df['Gender'].unique())
# Out:
# ['Female' 'Male']

# %%
df['Gender'] = df['Gender'].str.strip().str.lower()
print(df['Gender'].unique())
# Out:
# ['female' 'male']

# %%
df['Gender'] = df['Gender'].map({'male': 0, 'female': 1})

# %%
df['Gender']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    0
# 9999    1
# Name: Gender, Length: 10000, dtype: int64

# %%
from sklearn import preprocessing

# %%
enc = preprocessing.OneHotEncoder()

enc.fit(np.array(df['Geography']).reshape(-1,1))
# Out:
# OneHotEncoder()

# %%
pd.DataFrame.sparse.from_spmatrix(enc.transform(np.array(df['Geography']).reshape(-1,1)))
# Out:
#         0    1    2
# 0     1.0    0    0
# 1       0    0  1.0
# 2     1.0    0    0
# 3     1.0    0    0
# 4       0    0  1.0
# ...   ...  ...  ...
# 9995  1.0    0    0
# 9996  1.0    0    0
# 9997  1.0    0    0
# 9998    0  1.0    0
# 9999  1.0    0    0
#
# [10000 rows x 3 columns]

# %%
df = pd.get_dummies(df, columns=['Geography'], dtype=int)
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Gender  Age  Tenure  \
# 0             1    15634602   Hargrave          619       1   42       2
# 1             2    15647311       Hill          608       1   41       1
# 2             3    15619304       Onio          502       1   42       8
# 3             4    15701354       Boni          699       1   39       1
# 4             5    15737888   Mitchell          850       1   43       2
# ...         ...         ...        ...          ...     ...  ...     ...
# 9995       9996    15606229   Obijiaku          771       0   39       5
# 9996       9997    15569892  Johnstone          516       0   35      10
# 9997       9998    15584532        Liu          709       1   36       7
# 9998       9999    15682355  Sabbatini          772       0   42       3
# 9999      10000    15628319     Walker          792       1   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.drop(['RowNumber', 'CustomerId','Surname'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.drop(['RowNumber', 'CustomerId','Surname'],axis=1, inplace=True)
#       2 df
#
# File c:\Users\halima\OneDrive - Unimore\Desktop\rep\ExerciseNumpy\venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
# ...

# %%
df
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       1   42       2       0.00              1          1
# 1             608       1   41       1   83807.86              1          0
# 2             502       1   42       8  159660.80              3          1
# 3             699       1   39       1       0.00              2          0
# 4             850       1   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       0   39       5       0.00              2          1
# 9996          516       0   35      10   57369.61              1          1
# 9997          709       1   36       7       0.00              1          0
# 9998          772       0   42       3   75075.31              2          1
# 9999          792       1   28       4  130142.79              1          1
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop('Exited',axis=1), df['Exited'], test_size=0.75, random_state=0, stratify=df['Exited'])

# %%
X_train
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 8354          556       1   31       1  128663.81              2          1
# 5907          526       0   66       7  132044.60              2          1
# 297           687       1   44       7       0.00              3          1
# 7561          635       0   41       4  103544.88              2          1
# 3271          584       0   32       9   85534.83              1          0
# ...           ...     ...  ...     ...        ...            ...        ...
# 9225          594       1   32       4  120074.97              2          1
# 4859          794       1   22       4  114440.24              1          1
# 3264          738       0   35       5  161274.05              2          1
# 9845          590       1   38       9       0.00              2          1
# 2732          623       1   48       1  108076.33              1          1
#
# ...

# %% [markdown]
# DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)

# %%
#accuracy
from sklearn.metrics import accuracy_score


accuracy_score(y_test, y_pred)
# Out:
# 0.7802666666666667

# %%
df['NewFeature'] = (df['EstimatedSalary'] * df['EstimatedSalary'] + df['Balance']) /2

# %%
df['NewFeature']
# Out:
# 0       5.135798e+09
# 1       6.332958e+09
# 2       6.490281e+09
# 3       4.401718e+09
# 4       3.127210e+09
#             ...
# 9995    4.634018e+09
# 9996    5.171450e+09
# 9997    8.855980e+08
# 9998    4.314176e+09
# 9999    7.293329e+08
# Name: NewFeature, Length: 10000, dtype: float64
